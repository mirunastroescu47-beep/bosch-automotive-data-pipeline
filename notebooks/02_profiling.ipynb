# %%
from src.etl.profile_raw import profile_raw_data

profile_raw_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.etl.profile_raw import profile_raw_data
#       2
#       3 profile_raw_data()
#
# ModuleNotFoundError: No module named 'src'
