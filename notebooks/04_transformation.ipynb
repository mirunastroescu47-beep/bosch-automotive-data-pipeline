# %%
from src.etl.transformation import run_transformation

run_transformation()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.etl.transformation import run_transformation
#       2
#       3 run_transformation()
#
# ModuleNotFoundError: No module named 'src'
